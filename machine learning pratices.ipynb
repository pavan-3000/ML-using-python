# %%
from scikit_learn import linearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 from scikit_learn import linearRegression
#
# ModuleNotFoundError: No module named 'scikit_learn'

# %%
from matplotlib import pyplot as plt
from scipy import stats

# %%
x=[3,4,6,7,8,9,6,8,6]
y=[5,6,7,3,6,7,8,3,7]
plt.scatter(x,y)
plt.show()

# %%
slope,intercept,r,p,std_err  = stats.linregress(x,y)
def my(x):
    return slope*x+intercept
mymodel=list(map(my,x))
m=my(10)
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()
